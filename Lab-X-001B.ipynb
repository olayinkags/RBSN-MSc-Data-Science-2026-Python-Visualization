# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Labels for each bar.
salesData = [{'SalesYear':2018, 'East': 100, 'West':  90, 'North': 110, 'South': 120, 'Total': 420},
             {'SalesYear':2019, 'East': 105, 'West':  95, 'North': 115, 'South': 125, 'Total': 440},
             {'SalesYear':2020, 'East': 108, 'West':  92, 'North': 118, 'South': 130, 'Total': 448},
             {'SalesYear':2021, 'East': 110, 'West': 100, 'North': 120, 'South': 128, 'Total': 458},
             {'SalesYear':2022, 'East': 112, 'West':  98, 'North': 116, 'South': 132, 'Total': 458},
             {'SalesYear':2023, 'East': 107, 'West': 103, 'North': 121, 'South': 135, 'Total': 466},
             {'SalesYear':2024, 'East': 115, 'West': 105, 'North': 123, 'South': 131, 'Total': 474},
             {'SalesYear':2025, 'East': 118, 'West': 100, 'North': 122, 'South': 138, 'Total': 478},
             {'SalesYear':2026, 'East': 120, 'West': 104, 'North': 125, 'South': 136, 'Total': 485},
             {'SalesYear':2027, 'East': 122, 'West': 101, 'North': 129, 'South': 134, 'Total': 486},
             {'SalesYear':2028, 'East': 124, 'West': 108, 'North': 128, 'South': 140, 'Total': 500},
             {'SalesYear':2029, 'East': 127, 'West': 110, 'North': 130, 'South': 137, 'Total': 504},
             {'SalesYear':2030, 'East': 126, 'West': 107, 'North': 133, 'South': 139, 'Total': 505},
             {'SalesYear':2031, 'East': 129, 'West': 111, 'North': 132, 'South': 141, 'Total': 513},
             {'SalesYear':2032, 'East': 131, 'West': 109, 'North': 134, 'South': 138, 'Total': 512},
             {'SalesYear':2033, 'East': 133, 'West': 113, 'North': 135, 'South': 142, 'Total': 523},
             {'SalesYear':2034, 'East': 130, 'West': 115, 'North': 137, 'South': 145, 'Total': 527},
             {'SalesYear':2035, 'East': 135, 'West': 117, 'North': 139, 'South': 143, 'Total': 534},
             {'SalesYear':2036, 'East': 138, 'West': 114, 'North': 141, 'South': 146, 'Total': 539},
             {'SalesYear':2037, 'East': 140, 'West': 118, 'North': 142, 'South': 149, 'Total': 549},
             {'SalesYear':2038, 'East': 142, 'West': 116, 'North': 145, 'South': 147, 'Total': 550},
             {'SalesYear':2039, 'East': 144, 'West': 121, 'North': 147, 'South': 150, 'Total': 562},
             {'SalesYear':2040, 'East': 146, 'West': 119, 'North': 149, 'South': 152, 'Total': 566}
             ]

# %%
df = pd.DataFrame(salesData)

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# draw the stacked area chart
ax.stackplot(
    # defines the x-axis data source
    df.SalesYear,

    # defines the y-axis data sources
    df.West,
    df.East,
    df.North,
    df.South,
    df.Total,
    labels=["West", "East", "North", "South", "Total"],
    colors=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd"],
    alpha=0.8,
)

# add line markers on top for readability
ax.plot(df.SalesYear, df.West, marker="o", linestyle="-", color="#1f77b4", markersize=5)
# ax.plot(df.SalesYear, df.East, marker="s", linestyle="-", color="#ff7f0e", markersize=5)
# ax.plot(df.SalesYear, df.North, marker="D", linestyle="-", color="#2ca02c", markersize=5)
# ax.plot(df.SalesYear, df.South, marker="^", linestyle="-", color="#d62728", markersize=5)
ax.plot(df.SalesYear, df.Total, marker="X", linestyle="-", color="#9467bd", markersize=6)

ax.legend(loc="upper left")
ax.set_title("Sales by Region with Total and Markers")
ax.set_xlabel("Sales Year")
ax.set_ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')
